# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

df = pd.read_excel(r'/Users/alongeandrews/Desktop/UFC_data.xls')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5144 entries, 0 to 5143
# Columns: 145 entries, R_fighter to R_age
# dtypes: bool(1), datetime64[ns](1), float64(106), int64(29), object(8)
# memory usage: 5.7+ MB

# %%
df.head()
# Out:
#               R_fighter       B_fighter          Referee       date  \
# 0          Henry Cejudo   Marlon Moraes     Marc Goddard 2019-06-08
# 1  Valentina Shevchenko     Jessica Eye  Robert Madrigal 2019-06-08
# 2         Tony Ferguson  Donald Cerrone  Dan Miragliotta 2019-06-08
# 3         Jimmie Rivera        Petr Yan  Kevin MacDonald 2019-06-08
# 4           Tai Tuivasa   Blagoy Ivanov  Dan Miragliotta 2019-06-08
#
#                  location Winner  title_bout       weight_class  no_of_rounds  \
# 0  Chicago, Illinois, USA    Red        True       Bantamweight             5
# 1  Chicago, Illinois, USA    Red        True  Women's Flyweight             5
# 2  Chicago, Illinois, USA    Red       False        Lightweight             3
# 3  Chicago, Illinois, USA   Blue       False       Bantamweight             3
# 4  Chicago, Illinois, USA   Blue       False        Heavyweight             3
#
#    B_current_lose_streak  ...  R_win_by_KO/TKO  R_win_by_Submission  \
# ...

# %%
plt.figure(figsize = (16,8))
df['no_of_rounds'].value_counts(normalize = True).plot(kind = 'pie', pctdistance=1.1, 
                                                       labeldistance=1.2, autopct='%0.1f%%')

# %%
plt.figure(figsize = (16,8))
df['title_bout'].value_counts(normalize = True).plot(kind = 'pie', pctdistance=1.1, 
                                                       labeldistance=1.2, autopct='%0.1f%%')

# %%
df['title_bout'].value_counts()
# Out:
# False    4809
# True      335
# Name: title_bout, dtype: int64

# %%
df['B_Stance'].value_counts(normalize = True)
# Out:
# Orthodox       0.768104
# Southpaw       0.195587
# Switch         0.033701
# Open Stance    0.001805
# Sideways       0.000802
# Name: B_Stance, dtype: float64

# %%
plt.figure(figsize = (16,8))

df2 = df[df['title_bout']== True]
df2['no_of_rounds'].value_counts(normalize = True).plot(kind = 'pie', pctdistance=1.1, 
                                                       labeldistance=1.2, autopct='%0.1f%%')

# %%
df2['B_Stance'].value_counts(normalize = True)
# Out:
# Orthodox       0.750000
# Southpaw       0.212500
# Switch         0.034375
# Open Stance    0.003125
# Name: B_Stance, dtype: float64

# %%
df2
# Out:
#                  R_fighter        B_fighter               Referee       date  \
# 0             Henry Cejudo    Marlon Moraes          Marc Goddard 2019-06-08
# 1     Valentina Shevchenko      Jessica Eye       Robert Madrigal 2019-06-08
# 38          Rose Namajunas  Jessica Andrade          Marc Goddard 2019-05-11
# 86            Max Holloway   Dustin Poirier           Blake Grice 2019-04-13
# 87         Kelvin Gastelum  Israel Adesanya          Marc Goddard 2019-04-13
# ...                    ...              ...                   ...        ...
# 5098            Dan Severn    Dave Beneteau         John McCarthy 1995-04-07
# 5107          Royce Gracie       Dan Severn         John McCarthy 1994-12-16
# 5115          Steve Jennum    Harold Howard         John McCarthy 1994-09-09
# 5121          Royce Gracie    Patrick Smith         John McCarthy 1994-03-11
# 5136          Royce Gracie   Gerard Gordeau  Joao Alberto Barreto 1993-11-12
#
# ...

# %%
df2['R_age'].plot(kind = 'hist')
